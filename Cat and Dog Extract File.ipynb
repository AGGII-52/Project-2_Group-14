# %%
import numpy as np
import pandas as pd
import os

# %%
path_to_file = os.path.join(".", "Resources", "Rowan County Adoptable Dog List - Cat Info.csv")
RCA_cat_df = pd.read_csv(path_to_file)
RCA_cat_df.head()
# Out:
#      Animal ID Kennel #       Name          Description     Sex    Age  S/N  \
# 0  X   A124749      K18   Fraulein  DSH Brw Tabby W/Wht  Female  Adult  NaN
# 1  X   A124782      K17     Brogan          DSH Brn Tab    Male  Adult  NaN
# 2  X   A124797       K6     Merica       DSH Silver Tab    Male  Adult  NaN
# 3  X   A124800       K5  Momma Kat     DSH Dilute Torti  Female  Adult  NaN
# 4  X   A124661      Q25     Mellow          DSH Blk/Wht    Male  Adult  NaN
#
#   FIS Intake  ...  Sex.1 Age.1 S/N.1 FIS.1  Intake.1  Unnamed: 27  \
# 0   Y  Stray  ...    NaN   NaN   NaN   NaN       NaN          NaN
# 1   Y  Stray  ...    NaN   NaN   NaN   NaN       NaN          NaN
# 2   Y  Stray  ...    NaN   NaN   NaN   NaN       NaN          NaN
# 3   Y  Stray  ...    NaN   NaN   NaN   NaN       NaN          NaN
# 4   Y  Stray  ...    NaN   NaN   NaN   NaN       NaN          NaN
#
#    Available.1  Last Day.1  Notes  Applications.1
# 0          NaN         NaN    NaN             NaN
# 1          NaN         NaN    NaN             NaN
# 2          NaN         NaN    NaN             NaN
# 3          NaN         NaN    NaN             NaN
# 4          NaN         NaN    NaN             NaN
#
# [5 rows x 32 columns]

# %%
path_to_file = os.path.join(".", "Resources", "Rowan County Adoptable Dog List - Dog Info.csv")
RCA_dog_df = pd.read_csv(path_to_file)
RCA_dog_df.head()
# Out:
#   a125056 Animal ID Kennel #         Name          Breed Description     Sex  \
# 0       X   A122246        3       Chance  Catahoula Mix  Blue Merle    Male
# 1       X   A125012       P9        Alice       Chih Mix         Tan  Female
# 2       X   A125014       19       Ocelot        Lab Mix       Black    Male
# 3       X   A125017        5  Surfer Girl   Shepherd Mix   Black/Tan  Female
# 4       X   A125031       10        Judge   German Shep.     Tan/Blk    Male
#
#      Age  S/N  FIS Intake  Unnamed: 11   Available    Last Day      Outcome  \
# 0  2 Yrs  Yes  NaN  Owner          NaN   10/9/2020  10/23/2020  Rescue Only
# 1  Adult  NaN    Y  Stray      28144.0  10/22/2020  10/31/2020      Adopted
# 2  10 yr   No  NaN  Stray      28146.0  10/22/2020  10/31/2020      Adopted
# 3  2 Yrs   No  NaN  Stray      28147.0  10/23/2020   11/2/2020          NaN
# 4  6 Yrs   No  NaN  Owner          NaN  10/20/2020   11/3/2020  Rescue Only
#
#   Applications
# 0          NaN
# 1     10/22/20
# 2     10/22/20
# 3            X
# 4          NaN

# %%
path_to_file = os.path.join(".", "Resources", "SoCo-Animal_Shelter_Intake_and_Outcome.csv")
SoCO_animals_df = pd.read_csv(path_to_file)
SoCO_animals_df.head()
# Out:
#     Name Type              Breed      Color       Sex   Size Date Of Birth  \
# 0    SKY  DOG      GERM SHEPHERD  BLACK/TAN    Female    MED           NaN
# 1   COCO  DOG             BEAGLE   TRICOLOR  Neutered  SMALL    04/06/2015
# 2  SUZIE  DOG  LABRADOR RETR/MIX      BLACK    Spayed  LARGE    01/23/2011
# 3    NaN  DOG  GERM SHEPHERD/MIX   TRICOLOR   Unknown    MED           NaN
# 4  FELIX  CAT        DOMESTIC SH      BLACK  Neutered  KITTN    05/12/2018
#
#   Impound Number Kennel Number Animal ID  ...    Intake Subtype  \
# 0     K20-035118          DS69   A395686  ...             FIELD
# 1     K17-025093          DS83   A379968  ...             FIELD
# 2     K15-012348          DA34   A315553  ...  OVER THE COUNTER
# 3     K20-036188           VET   A398868  ...         FLD_CRUEL
# 4     K18-029084         LOBBY   A374683  ...  OVER THE COUNTER
#
#       Outcome Type        Outcome Subtype Intake Condition Outcome Condition  \
# 0  RETURN TO OWNER  OVER THE COUNTER_CALL          HEALTHY           HEALTHY
# 1         TRANSFER             NC AN FRND          UNKNOWN           HEALTHY
# 2         ADOPTION               INTERNET          HEALTHY           HEALTHY
# 3  RETURN TO OWNER                MEDICAL          UNKNOWN           HEALTHY
# 4         ADOPTION                 WALKIN          HEALTHY           HEALTHY
#
#   Intake Jurisdiction Outcome Jurisdiction Outcome Zip Code  \
# 0              COUNTY               COUNTY          95404.0
# 1          SANTA ROSA        OUT OF COUNTY          95758.0
# 2          SANTA ROSA           SANTA ROSA          95404.0
# 3          SANTA ROSA                  NaN              NaN
# 4          SANTA ROSA               COUNTY          95407.0
#
#                         Location Count
# 0  95404(38.458384, -122.675588)     1
# 1  95758(38.424655, -121.438065)     1
# 2  95404(38.458384, -122.675588)     1
# 3                            NaN     1
# 4  95407(38.403734, -122.736775)     1
#
# [5 rows x 24 columns]
